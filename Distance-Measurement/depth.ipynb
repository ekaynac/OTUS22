# %%
# import the necessary packages
import argparse
import cv2

# %%
# initialize the list of reference points and boolean indicating
# whether cropping is being performed or not
refPt = []
line = False
def line(event, x, y, flags, param):
	# grab references to the global variables
	global refPt, line
	# if the left mouse button was clicked, record the starting
	# (x, y) coordinates and indicate that cropping is being
	# performed
	if event == cv2.EVENT_LBUTTONDOWN:
		refPt = [(x, y)]
		line = True
	# check to see if the left mouse button was released
	elif event == cv2.EVENT_LBUTTONUP:
		# record the ending (x, y) coordinates and indicate that
		# the cropping operation is finished
		refPt.append((x, y))
		line = False
		# draw a rectangle around the region of interest
		cv2.line(image,refPt[0], refPt[1],(0,0,255),5)
		print("widthPx: {}\nheightPx: {}".format(abs(refPt[0][0]-refPt[1][0]),abs(refPt[0][1]-refPt[1][1])))

# %%
cap = cv2.VideoCapture(0)

success, image = cap.read()
cv2.namedWindow("image")
cv2.setMouseCallback("image", line)

while True:

    cv2.imshow("image", image)

    key = cv2.waitKey(1)

    if key == ord("r"):
        success, image = cap.read()
        
    
    if key==ord('q'):
        break


cap.release()
cv2.destroyAllWindows()
# Out:
# widthPx: 0
# heightPx: 0
# widthPx: 213
# heightPx: 113
# widthPx: 363
# heightPx: 16
# widthPx: 133
# heightPx: 297
# widthPx: 102
# heightPx: 105
# widthPx: 54
# heightPx: 62
# widthPx: 0
# heightPx: 0

# %%
# kamera için focal lenght hesabı yapılacak
widthPxTest= 500       # detectordan çekilecek
depthTest=30 #CM        # elle girilecek
widthTest=20 #CM          # elle girilecek
focalLen = widthPxTest * depthTest / widthTest
print(focalLen)
# Out:
# 750.0

# %%
# initialize the list of reference points and boolean indicating
# whether cropping is being performed or not
refPt = []
line = False
widthPx = 1
def Cloneline(event, x, y, flags, param):
	# grab references to the global variables
	global refPt, line, widthPx
	# if the left mouse button was clicked, record the starting
	# (x, y) coordinates and indicate that cropping is being
	# performed
	if event == cv2.EVENT_LBUTTONDOWN:
		refPt = [(x, y)]
		line = True
	# check to see if the left mouse button was released
	elif event == cv2.EVENT_LBUTTONUP:
		# record the ending (x, y) coordinates and indicate that
		# the cropping operation is finished
		refPt.append((x, y))
		line = False
		# draw a rectangle around the region of interest
		cv2.line(clone,refPt[0], refPt[1],(0,0,255),5)
		print("widthPx: {}\nheightPx: {}".format(abs(refPt[0][0]-refPt[1][0]),abs(refPt[0][1]-refPt[1][1])))
		widthPx= abs(refPt[0][0]-refPt[1][0])

# %%
cap = cv2.VideoCapture(0)

cv2.namedWindow("clone")
cv2.setMouseCallback("clone", Cloneline)
success, image = cap.read()
clone = image.copy()
while True:
    success, image = cap.read()
    

    cv2.imshow("clone", clone)
    cv2.imshow("image", image)
    
    
    width =  20           # Perspektif göz ardı edilerek kanat açıklığı width sayılabilir
             # Detectordan çekilecek
    depth = width * focalLen / widthPx # cm
    print("Depth: {} cm".format(depth)) # cm
    key = cv2.waitKey(1)

    if key == ord("r"):
        clone = image.copy()
        
    
    if key==ord('q'):
        break


cap.release()
cv2.destroyAllWindows()
# Out:
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# Depth: 15000.0 cm
# ...

# %%
width =  20           # Perspektif göz ardı edilerek kanat açıklığı width sayılabilir
widthPx= 269         # Detectordan çekilecek
depth = width * focalLen / widthPx

# %%
print(depth)
# Out:
# 55.762081784386616
